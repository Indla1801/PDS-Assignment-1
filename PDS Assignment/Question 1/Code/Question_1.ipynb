# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("Frailty_data.csv", encoding="ISO-8859-1")

# %%
print(df)
# Out:
#    Height   Weight   Age  Grip strength Frailty
# 0     65.8      112   30             30       N
# 1     71.5      136   19             31       N
# 2     69.4      153   45             29       N
# 3     68.2      142   22             28       Y
# 4     67.8      144   29             24       Y
# 5     68.7      123   50             26       N
# 6     69.8      141   51             22       Y
# 7     70.1      136   23             20       Y
# 8     67.9      112   17             19       N
# 9     66.8      120   39             31       N

# %%
cleaned_data = df.dropna()

# %%
print(cleaned_data)
# Out:
#    Height   Weight   Age  Grip strength Frailty
# 0     65.8      112   30             30       N
# 1     71.5      136   19             31       N
# 2     69.4      153   45             29       N
# 3     68.2      142   22             28       Y
# 4     67.8      144   29             24       Y
# 5     68.7      123   50             26       N
# 6     69.8      141   51             22       Y
# 7     70.1      136   23             20       Y
# 8     67.9      112   17             19       N
# 9     66.8      120   39             31       N

# %%
cleaned_data = cleaned_data.drop_duplicates()

# %%
print(cleaned_data)
# Out:
#    Height   Weight   Age  Grip strength Frailty
# 0     65.8      112   30             30       N
# 1     71.5      136   19             31       N
# 2     69.4      153   45             29       N
# 3     68.2      142   22             28       Y
# 4     67.8      144   29             24       Y
# 5     68.7      123   50             26       N
# 6     69.8      141   51             22       Y
# 7     70.1      136   23             20       Y
# 8     67.9      112   17             19       N
# 9     66.8      120   39             31       N

# %%
missing_values = cleaned_data.isnull().sum()

# %%
print(missing_values)
# Out:
# Height           0
# Weight           0
# Age              0
# Grip strength    0
# Frailty          0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(cleaned_data['Age'], bins=10, kde=True, color='blue')
plt.title('Distribution of Age', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
